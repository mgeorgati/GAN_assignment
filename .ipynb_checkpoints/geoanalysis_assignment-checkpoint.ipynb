# %% [markdown]
# # Final Assignment
# Python for Geospatial Analysis PhD Course @ AAU CPH, Spring 2020
# Here is a Jupyter Notebook that performs the following steps:
# 1. Raster Analysis
# 2. Spatial Autocorrelation

# %% [markdown]
# Import necessary libraries

# %%
#Import necessary libraries
import os
import pandas as pd
import rasterio
from rasterio.plot import plotting_extent
import bokeh
import numpy as np
import matplotlib as mlp
from rasterio.plot import show
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# Open the countries dataset and define path for projections

# %%
countries_tif = rasterio.open('countries.tif')
path = os.getcwd() + '\\popdynamics\\SSP4'
#tif = rasterio.open('C:\\Users\\NM12LQ\\OneDrive - Aalborg Universitet\\PhDCourses\\3. Python\\Geospatial-Analysis-Notebooks_assignment\\popdynamics\\SSP4\\Total\\GeoTIFF\\ssp4_2020.tif')

# %% [markdown]
# ### Countries dataset_ details
# Print some information about the countries dataset

# %%
print("The file is called", countries_tif.name)
print()
print("It is", countries_tif.width, "x",countries_tif.height,"pixels big")
print()
print("It covers the following extent:",countries_tif.bounds)
print()
print("It is in the following CRS:",countries_tif.crs)
# Out:
# The file is called countries.tif
#
# It is 2880 x 1117 pixels big
#
# It covers the following extent: BoundingBox(left=-180.0, bottom=-55.875, right=180.0, top=83.75)
#
# It is in the following CRS: EPSG:4326

# %% [markdown]
# ### Reading raster data
# Access the raster band through its index and read the raster in a Numpy N-D array. Then plot a map

# %%
{i: dtype for i, dtype in zip(countries_tif.indexes, countries_tif.dtypes)}
# Out:
# {1: 'float64'}

# %%
countries_tif.indexes
# Out:
# (1,)

# %%
countries = countries_tif.read(1)
countries
# Out:
# array([[-99., -99., -99., ..., -99., -99., -99.],
#        [-99., -99., -99., ..., -99., -99., -99.],
#        [-99., -99., -99., ..., -99., -99., -99.],
#        ...,
#        [-99., -99., -99., ..., -99., -99., -99.],
#        [-99., -99., -99., ..., -99., -99., -99.],
#        [-99., -99., -99., ..., -99., -99., -99.]])

# %%
plt.figure(figsize=(14, 14))
show((countries_tif, 1), title='Countries', cmap='gist_rainbow')

# %% [markdown]
# How many countries are included?

# %%
countrylist= np.unique(countries).tolist()
num_countries=len(countrylist)-1 #-99= water
print('There are: {} countries'.format(num_countries) )
# Out:
# There are: 235 countries

# %% [markdown]
# Select a country to plot the projected total and urban population from 2010 to 2100 as a line chart.

# %%
rural = []
urban = []
total = []
Years = []

for subdir, dirs, files in os.walk(path):
    for file in files:
        #print(subdir,file)
        if file.endswith(".tif"):
            name = file.split(".tif")[0]
            #print(name)
            if "rur" in file:
                nameRural = file.split(".tif")[0]
                directories_rural=os.path.join(subdir, file)
                rural.append(directories_rural)
                #print()
            if "urb" in file:
                nameUrban = file.split(".tif")[0]
                directories_urban=os.path.join(subdir, file)
                urban.append(directories_urban)
            if "_" in file:
                nameTotal = file.split("_")[1]
                years = nameTotal.split(".tif")[0]        
                directories_total=os.path.join(subdir, file)
                total.append(directories_total)
                Years.append(years)

# %% [markdown]
# Define a list of files for urban and total

# %%
def plot_LineChart (country):
    UrbanPop = []
    TotalPop = []
    RuralPop = []
    for i in urban:
        tif_i=rasterio.open(i)
        pop_i = tif_i.read(1)
        urban_pop=np.sum(pop_i[country])
        UrbanPop.append(urban_pop)

    for x in total:
        tif_x=rasterio.open(x)
        pop_x = tif_x.read(1)
        total_pop=np.sum(pop_x[country])
        TotalPop.append(total_pop)

    for y in rural:
        tif_y=rasterio.open(y)
        pop_y = tif_y.read(1)
        rural_pop=np.sum(pop_y[country])
        RuralPop.append(rural_pop)
    
    # Data
    df=pd.DataFrame({'x': Years, 'y': TotalPop, 'y1': UrbanPop })

    # multiple line plot
    plt.plot( 'x', 'y', data=df, marker='', color='blue', linewidth=2, label="Total Population")
    plt.plot( 'x', 'y1', data=df, marker='', color='skyblue', linewidth=2, label="Urban Population")
    #plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="Rural Population" )
    plt.legend()

# %%
albany = countries == 208
plot_LineChart (albany)
# Out:
# C:\Users\NM12LQ\Anaconda3\envs\geoanalysis-env\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: Second argument 'y' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
# C:\Users\NM12LQ\Anaconda3\envs\geoanalysis-env\lib\site-packages\ipykernel_launcher.py:28: RuntimeWarning: Second argument 'y1' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.

# %%
france_2010 = rasterio.open('france_ssp2100.tif')
france_pop2010 = france_2010.read(1)
popFrance=np.sum(france_pop2010)
popFrance
# Out:
# -2086046121

# %%
tif1 = rasterio.open('C:\\Users\\NM12LQ\\OneDrive - Aalborg Universitet\\PhDCourses\\3. Python\\Geospatial-Analysis-Notebooks_assignment\\popdynamics\\SSP4\\Total\\GeoTIFF\\ssp4_2020.tif')
tif2 = rasterio.open('C:\\Users\\NM12LQ\\OneDrive - Aalborg Universitet\\PhDCourses\\3. Python\\Geospatial-Analysis-Notebooks_assignment\\popdynamics\\SSP4\\Total\\GeoTIFF\\ssp4_2050.tif')
tif3 = rasterio.open('C:\\Users\\NM12LQ\\OneDrive - Aalborg Universitet\\PhDCourses\\3. Python\\Geospatial-Analysis-Notebooks_assignment\\popdynamics\\SSP4\\Total\\GeoTIFF\\ssp4_2090.tif')
fig, (axr, axg, axb) = pyplot.subplots(1,3, figsize=(21,7))
show((tif1, 1), ax=axr, cmap='gist_rainbow', title='red channel')

show((tif2, 1), ax=axg, cmap='gist_rainbow', title='green channel')

show((tif3, 1), ax=axb, cmap='gist_rainbow', title='blue channel')

pyplot.show()

# %% [markdown]
# ### Raster Analysis 2
# Even though in most of the countries the population seems to increase until 2050, in the 2nd half of the centure the population declines. In other words, a lower number of residents will inhabite in most areas in 2100 compared to 2010. This part considers only the first and the last estimations regardless the intermediate flactuations and a global raster is generated showing only the cells that are projected to lose population and indicates how much the population in those cells is projected to decline between 2010 and 2100.

# %%
#open the datasets
ssp4_2100 = rasterio.open('popdynamics\\SSP4\\Total\\GeoTIFF\\ssp4_2100.tif')
ssp4_2010 = rasterio.open('popdynamics\\SSP4\\Total\\GeoTIFF\\ssp4_2010.tif')

# %%
#read the datasets
pop2100 = ssp4_2100.read(1)
pop2010 = ssp4_2010.read(1)

# %%
pop2010.shape
ssp4_2100.crs
# Out:
# CRS.from_epsg(4326)

# %%
diff = pop2010 - pop2100
diff.shape
# Out:
# (1117, 2880)

# %% [markdown]
# The cells that lose population are shown in the following plot

# %%
from matplotlib.colors import LogNorm
plt.figure(figsize=(14, 5))

imgplot = plt.imshow(diff>0, norm=LogNorm(), cmap='gist_heat_r')
plt.colorbar()

# %% [markdown]
# The raster is generated after compression

# %%
def compress(inputfile, outputfile, layer, compression, datatype):
    
    with rasterio.Env():

        # Write an array as a raster band to a new 8-bit file. For
        # the new file's profile, we start with the profile of the source
        profile = inputfile.profile

        # And then change the band count to 1, set the
        # dtype to uint8, and specify LZW compression.
        profile.update(
            dtype=datatype,
            count=1,
            compress=compression)

        with rasterio.open(outputfile, 'w', **profile) as dst:
            dst.write(layer.astype(datatype),1)

# %%
diff[diff < 0] = 0
diff.shape
# Out:
# (1117, 2880)

# %%
#compress and save the geotiff
compress(ssp4_2100, 'pop-difference-lzw.tif', diff, 'lzw', rasterio.float32)

# %% [markdown]
# ## Spatial autocorrelation 1

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import contextily as ctx
import libpysal 
from libpysal import weights
from pysal.explore import esda
from pysal.viz import mapclassify

# %%
# Read the file 
fp = "ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp" 

data = gpd.read_file(fp) 
len(data.columns)
# Out:
# 95

# %%
mortality= pd.read_csv('under5mortality.csv')
mortality.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  ISO                                  Name  ChildMortality
# 0             1  AFG                           Afghanistan            67.9
# 1             4  ALB                               Albania             8.8
# 2             7  DZA                               Algeria            24.0
# 3            10  AND                               Andorra             3.3
# 4            13  AGO                                Angola            81.1
# ..          ...  ...                                   ...             ...
# 191         574  VEN  Venezuela (Bolivarian Republic of)**            30.9
# 192         577  VNM                              Viet Nam            20.9
# 193         580  YEM                                 Yemen            55.4
# 194         583  ZMB                                Zambia            60.0
# 195         586  ZWE                              Zimbabwe            50.3
#
# [196 rows x 4 columns]>

# %%
join= pd.merge(data, mortality, left_on='ISO_A3', right_on='ISO', how='left')
join
# Out:
#           featurecla  scalerank  LABELRANK                   SOVEREIGNT  \
# 0    Admin-0 country          1          6                         Fiji
# 1    Admin-0 country          1          3  United Republic of Tanzania
# 2    Admin-0 country          1          7               Western Sahara
# 3    Admin-0 country          1          2                       Canada
# 4    Admin-0 country          1          2     United States of America
# ..               ...        ...        ...                          ...
# 172  Admin-0 country          1          5           Republic of Serbia
# 173  Admin-0 country          1          6                   Montenegro
# 174  Admin-0 country          1          6                       Kosovo
# 175  Admin-0 country          1          5          Trinidad and Tobago
# 176  Admin-0 country          1          3                  South Sudan
#
#     SOV_A3  ADM0_DIF  LEVEL               TYPE                        ADMIN  \
# 0      FJI         0      2  Sovereign country                         Fiji
# 1      TZA         0      2  Sovereign country  United Republic of Tanzania
# 2      SAH         0      2      Indeterminate               Western Sahara
# 3      CAN         0      2  Sovereign country                       Canada
# 4      US1         1      2            Country     United States of America
# ..     ...       ...    ...                ...                          ...
# 172    SRB         0      2  Sovereign country           Republic of Serbia
# 173    MNE         0      2  Sovereign country                   Montenegro
# 174    KOS         0      2  Sovereign country                       Kosovo
# 175    TTO         0      2  Sovereign country          Trinidad and Tobago
# 176    SDS         0      2  Sovereign country                  South Sudan
#
#     ADM0_A3  ...                    NAME_RU              NAME_SV  \
# 0       FJI  ...                      Фиджи                 Fiji
# 1       TZA  ...                   Танзания             Tanzania
# 2       SAH  ...            Западная Сахара           Västsahara
# 3       CAN  ...                     Канада               Kanada
# 4       USA  ...  Соединённые Штаты Америки                  USA
# ..      ...  ...                        ...                  ...
# 172     SRB  ...                     Сербия              Serbien
# 173     MNE  ...                 Черногория           Montenegro
# 174     KOS  ...          Республика Косово               Kosovo
# 175     TTO  ...          Тринидад и Тобаго  Trinidad och Tobago
# 176     SDS  ...                Южный Судан             Sydsudan
#
#                          NAME_TR             NAME_VI  NAME_ZH  \
# 0                           Fiji                Fiji       斐濟
# 1                       Tanzanya            Tanzania     坦桑尼亚
# 2                     Batı Sahra          Tây Sahara     西撒哈拉
# 3                         Kanada              Canada      加拿大
# 4    Amerika Birleşik Devletleri              Hoa Kỳ       美国
# ..                           ...                 ...      ...
# 172                    Sırbistan              Serbia     塞尔维亚
# 173                      Karadağ          Montenegro    蒙特內哥羅
# 174                       Kosova              Kosovo      科索沃
# 175           Trinidad ve Tobago  Trinidad và Tobago  千里達及托巴哥
# 176                  Güney Sudan           Nam Sudan      南苏丹
#
#                                               geometry  Unnamed: 0  ISO  \
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...       181.0  FJI
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...       559.0  TZA
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...         NaN  NaN
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...        97.0  CAN
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...       562.0  USA
# ..                                                 ...         ...  ...
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...       460.0  SRB
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...       346.0  MNE
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...         NaN  NaN
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...       532.0  TTO
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...       487.0  SSD
#
#                             Name ChildMortality
# 0                           Fiji           25.3
# 1    United Republic of Tanzania           54.0
# 2                            NaN            NaN
# 3                         Canada            5.1
# 4                  United States            6.6
# ..                           ...            ...
# 172                       Serbia            5.7
# 173                   Montenegro            3.5
# 174                          NaN            NaN
# 175          Trinidad and Tobago           26.1
# 176                  South Sudan           96.4
#
# [177 rows x 99 columns]

# %%
# Maximum area 
max = join['ChildMortality'].max() 
# Minimum area 
min = join['ChildMortality'].min() 
# Mean area 
mean = join['ChildMortality'].mean()

print(min,max,mean)
# Out:
# 2.1 127.2 31.190243902439022

# %%
classi = mapclassify.EqualInterval(join['ChildMortality'], k=7)
classi
# Out:
# EqualInterval
#
#     Interval       Count
# ------------------------
# [   nan,  19.97] |    97
# ( 19.97,  37.84] |    28
# ( 37.84,  55.71] |    20
# ( 55.71,  73.59] |    11
# ( 73.59,  91.46] |    13
# ( 91.46, 109.33] |     4
# (109.33, 127.20] |     4

# %%
classi.bins
# Out:
# array([ 19.97142857,  37.84285714,  55.71428571,  73.58571429,
#         91.45714286, 109.32857143, 127.2       ])

# %%
def plotClassification(classi):
    # Set up the figure
    f, ax = plt.subplots(1, figsize=(9, 6))
    # Plot the kernel density estimation (KDE)
    sns.kdeplot(join['ChildMortality'], shade=True)
    # Add a blue tick for every value at the bottom of the plot (rugs)
    sns.rugplot(join['ChildMortality'], alpha=0.5)
    # Loop over each break point and plot a vertical red line
    for cut in classi.bins:
        plt.axvline(cut, color='red', linewidth=0.75)
    # Title
    ax.set_title(classi.name)
    # Display image
    plt.show()

# %%
plotClassification(classi)

# %%
classi = mapclassify.FisherJenks(join['ChildMortality'], k=7)
classi
# Out:
# FisherJenks
#
#  Interval    Count
# ------------------
# [nan, nan] |   177
# (nan, nan] |     0
# (nan, nan] |     0
# (nan, nan] |     0
# (nan, nan] |     0
# (nan, nan] |     0
# (nan, nan] |     0

# %%
classi = mapclassify.BoxPlot(join['ChildMortality'])
classi
# Out:
# BoxPlot
#
#     Interval       Count
# ------------------------
# [   nan, -68.25] |    13
# (-68.25,   7.80] |    46
# (  7.80,  21.00] |    43
# ( 21.00,  58.50] |    44
# ( 58.50, 134.55] |    31

# %%
# Set up the figure
f, axs = plt.subplots(2, figsize=(10, 10), gridspec_kw = {'height_ratios':[3, 1]})
# Plot the kernel density estimation (KDE)
sns.kdeplot(join['ChildMortality'], shade=True, ax=axs[0])
# Add a blue tick for every value at the bottom of the plot (rugs)
sns.rugplot(join['ChildMortality'], alpha=0.5, ax=axs[0])
# Loop over each break point and plot a vertical red line
for cut in classi.bins:
    axs[0].axvline(cut, color='red', linewidth=0.75)
# Box-Plot
axs[1].boxplot(join['ChildMortality'], vert=False)
# Set X axis manually
axs[1].set_xlim(axs[0].get_xlim())
# Title
axs[0].set_title(classi.name)
# Display image
plt.show()

# %%
for classification in ['equal_interval', 'quantiles', 'fisher_jenks']:
    f, ax = plt.subplots(1, figsize=(14, 7))
    join.plot(column='ChildMortality', scheme=classification, ax=ax, legend=True)
    ctx.add_basemap(ax, source=ctx.sources.ST_TONER_LITE)
    ax.set_axis_off()
    plt.axis('equal')
    plt.title(classification)
    plt.show()
# Out:
# C:\Users\NM12LQ\Anaconda3\envs\geoanalysis\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The "contextily.tile_providers" module is deprecated and will be removed in contextily v1.1. Please use "contextily.providers" instead.
#   """
# C:\Users\NM12LQ\Anaconda3\envs\geoanalysis\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The "contextily.tile_providers" module is deprecated and will be removed in contextily v1.1. Please use "contextily.providers" instead.
#   """
# C:\Users\NM12LQ\Anaconda3\envs\geoanalysis\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The "contextily.tile_providers" module is deprecated and will be removed in contextily v1.1. Please use "contextily.providers" instead.
#   """

# %%
f, axarr = plt.subplots(2,2)
axarr[0,0].imshow(diff, norm=LogNorm(), cmap='hot_r')
axarr[0,1].imshow(pop2100, norm=LogNorm(), cmap='hot_r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-87fa6391bf8a> in <module>
# ----> 1 f, axarr = plt.subplots(2,2)
#       2 axarr[0,0].imshow(diff, norm=LogNorm(), cmap='hot_r')
#       3 axarr[0,1].imshow(pop2100, norm=LogNorm(), cmap='hot_r')
#
# NameError: name 'plt' is not defined

# %%
diff = pop2010 - pop2100
diff_pop=diff[diff > 0]
diff_pop
# Out:
# array([10, 27, 24, ...,  1,  1,  1])

# %%
data = np.asarray([diff_pop])
data
# Out:
# array([[10, 27, 24, ...,  1,  1,  1]])

# %%
fig = sns.heatmap(data,cmap="YlGnBu").set_title('Population Decline 2010-2100')

# %%
plt.figure(figsize=(14, 14))
show((diff_pop, 1), title='Countries', cmap='gist_rainbow')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-171-9e52148e10e2> in <module>
#       1 plt.figure(figsize=(14, 14))
# ----> 2 show((diff_pop, 1), title='Countries', cmap='gist_rainbow')
#
# ~\Anaconda3\envs\geoanalysis-env\lib\site-packages\rasterio\plot.py in show(source, with_bounds, contour, contour_label_kws, ax, title, transform, adjust, **kwargs)
#      81
#      82     if isinstance(source, tuple):
# ---> 83         arr = source[0].read(source[1])
#      84         if len(arr.shape) >= 3:
#      85             arr = reshape_as_image(arr)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'read'
